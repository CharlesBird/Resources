# %% [markdown]
# # 机器学习、深度学习简介

# %% [markdown]
# ## 神经网络

# %% [markdown]
# ### 最小神经网络

# %% [markdown]
# ![clipboard.png](attachment:clipboard.png)

# %% [markdown]
# ### 激活函数sigmoid - 二分类逻辑斯蒂回归模型

# %% [markdown]
# ![clipboard.png](attachment:clipboard.png)

# %% [markdown]
# ### 多输出神经元

# %% [markdown]
# ![clipboard1.png](attachment:clipboard1.png)

# %% [markdown]
# ![clipboard2.png](attachment:clipboard2.png)

# %% [markdown]
# ![clipboard3.png](attachment:clipboard3.png)

# %% [markdown]
# ![clipboard4.png](attachment:clipboard4.png)

# %% [markdown]
# ### 损失函数

# %% [markdown]
# ![clipboard5.png](attachment:clipboard5.png)

# %% [markdown]
# ### 梯度下降

# %% [markdown]
# ![clipboard6.png](attachment:clipboard6.png)

# %% [markdown]
# ### 计算图模型

# %% [markdown]
# #### 命令式

# %%
x = 2
y = 3
b = 1
x * y + b
# Out:
# 7

# %% [markdown]
# #### 申明式编程

# %%
import theano.tensor as T
from theano import function
